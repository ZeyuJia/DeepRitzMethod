# %%
'''
test on a simple case
\Omega is the unit circle
\delta u = 1 
u=0 at border of \Omega
u=1/4*(x^2+y^2)-1/4
'''

import torch 
import torch.nn.functional as F
import numpy as np
import math
import matplotlib.pyplot as plt

torch.set_default_tensor_type('torch.FloatTensor')

m=10
learning_rate=1e-2  
iterations=8000  #default 10000
print_every_iter=100
beta=10 #coefficient for the regularization term in the loss expression, is set to be 1000 in section 3.1
n1=1000 #number of points in (0,1)^m
n2=100  #number of points on the border of (0,1)^m
n3=100  #number of points used for evaluating the error

class DeepRitzNet(torch.nn.Module):
    def __init__(self, m):
        super(DeepRitzNet, self).__init__()
        self.linear1=torch.nn.Linear(m,m)
        self.linear2=torch.nn.Linear(m,m)
        self.linear3=torch.nn.Linear(m,m)
        self.linear4=torch.nn.Linear(m,m)
        self.linear5=torch.nn.Linear(m,m)
        self.linear6=torch.nn.Linear(m,m)
        
        self.linear7=torch.nn.Linear(m,1)
    
    def forward(self, x):
        y=(F.relu(self.linear1(x)))**3
        y=(F.relu(self.linear2(x)))**3
        y+=x
        x=y
        y=(F.relu(self.linear3(x)))**3
        y=(F.relu(self.linear4(x)))**3
        y+=x
        x=y
        y=(F.relu(self.linear5(x)))**3
        y=(F.relu(self.linear6(x)))**3
        y+=x
        y=(F.relu(self.linear7(x)))**3
        return y

# %%
#U_groundtruth = 1/4*(x^2+y^2)-1/4
#take in a (m,) tensor (x, y, ...)
def U_groundtruth(t):
    re = (t[0]**2 + t[1]**2 - 1).item()/4
    return re

#turn a (2,) tensor/ndarray to a (m,) tensor
def zeropad(x_2):
    x_10=torch.zeros(m,)
    x_10[0]=x_2[0]
    x_10[1]=x_2[1]
    return x_10
    
#sample a (m,) tensor on the border of the unit circle
def on_sample():
    theta=np.random.rand()*2*math.pi
    re=np.zeros(m)
    re[0]=math.cos(theta)
    re[1]=math.sin(theta)
    re=torch.tensor(re,requires_grad=True)
    return re

#sample a (m,) tensor in the unit circle
def in_sample():
    r=np.random.rand()
    theta=np.random.rand()*2*math.pi
    re=np.zeros(m)
    re[0]=r*math.cos(theta)
    re[1]=r*math.sin(theta)
    re=torch.tensor(re,requires_grad=True)
    return re

# %%
model = DeepRitzNet(m)
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
in_error_iter=[] #record the error in Omega every print_every_iter=100 times
on_error_iter=[] #record the error on the border of Omega every print_every_iter=100 times

for i in range(iterations):
    #calculate the loss 
    loss=torch.zeros(1)
    for t in range(n1):
        #if I miss out the ".float()" there will be an error and I don't know why
        #It seems to have something to do with the usage of relu()**3 in DeepRitzNet
        x_input=in_sample()
        y=model(x_input.float())
        #there will be an error without "retain_graph=True" , I don't know why
        y.backward(retain_graph=True)
        loss+=0.5*((x_input.grad.float()[0])**2+(x_input.grad.float()[1])**2)-y
    loss/=n1
    
    regularization=torch.zeros(1)
    for t in range(n2):
        x_input=on_sample().float()
        y=model(x_input)
        regularization+=y**2   
    regularization*=beta/n2
    
    loss+=regularization
    
    #and step the optimizer
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    #print the error
    if((i+1)%print_every_iter==0):
        in_error=0
        on_error=0
        
        for t in range(n3):
            in_x_test=in_sample()
            in_error_instant=abs((model(in_x_test.float())-U_groundtruth(in_x_test.float())).item())
            in_error=max(in_error,in_error_instant)
            
            on_x_test=on_sample()
            on_error_instant=abs((model(on_x_test.float())-U_groundtruth(on_x_test.float())).item())
            on_error=max(on_error,on_error_instant)
            
        in_error_iter.append(in_error)
        on_error_iter.append(on_error)
        
        print("Error in Omega at the",i+1,"th iteration:",in_error)
        print("Error on the border of Omega at the",i+1,"th iteration:",on_error)
        
print("Traning Completed.")
# Out:
# Error in Omega at the 100 th iteration: 0.2575687766075134
# Error on the border of Omega at the 100 th iteration: 0.04490671679377556
# Error in Omega at the 200 th iteration: 0.2645265460014343
# Error on the border of Omega at the 200 th iteration: 0.04527539014816284
# Error in Omega at the 300 th iteration: 0.2821703851222992
# Error on the border of Omega at the 300 th iteration: 0.04841860756278038
# Error in Omega at the 400 th iteration: 0.2989506721496582
# Error on the border of Omega at the 400 th iteration: 0.056610673666000366
# Error in Omega at the 500 th iteration: 0.30295661091804504
# Error on the border of Omega at the 500 th iteration: 0.05734749883413315
# Error in Omega at the 600 th iteration: 0.30542615056037903
# Error on the border of Omega at the 600 th iteration: 0.059029243886470795
# Error in Omega at the 700 th iteration: 0.30787745118141174
# Error on the border of Omega at the 700 th iteration: 0.060716770589351654
# Error in Omega at the 800 th iteration: 0.31111764907836914
# Error on the border of Omega at the 800 th iteration: 0.06324215233325958
# Error in Omega at the 900 th iteration: 0.31502029299736023
# Error on the border of Omega at the 900 th iteration: 0.06535770744085312
# Error in Omega at the 1000 th iteration: 0.32057464122772217
# Error on the border of Omega at the 1000 th iteration: 0.07008770853281021
# Error in Omega at the 1100 th iteration: 0.32764971256256104
# Error on the border of Omega at the 1100 th iteration: 0.0764286071062088
# Error in Omega at the 1200 th iteration: 0.3375752568244934
# Error on the border of Omega at the 1200 th iteration: 0.08130565285682678
# Error in Omega at the 1300 th iteration: 0.3505474925041199
# Error on the border of Omega at the 1300 th iteration: 0.08889744430780411
# Error in Omega at the 1400 th iteration: 0.37271764874458313
# Error on the border of Omega at the 1400 th iteration: 0.10032123327255249
# Error in Omega at the 1500 th iteration: 0.4196508824825287
# Error on the border of Omega at the 1500 th iteration: 0.11480201035737991
# Error in Omega at the 1600 th iteration: 0.6209044456481934
# Error on the border of Omega at the 1600 th iteration: 0.14341317117214203
# Error in Omega at the 1700 th iteration: 3.8304030895233154
# Error on the border of Omega at the 1700 th iteration: 0.276939332485199
# Error in Omega at the 1800 th iteration: 1.0638961791992188
# Error on the border of Omega at the 1800 th iteration: 0.10597802698612213
# Error in Omega at the 1900 th iteration: 2.344770669937134
# Error on the border of Omega at the 1900 th iteration: 0.160469189286232
# Error in Omega at the 2000 th iteration: 34.00984191894531
# Error on the border of Omega at the 2000 th iteration: 1.1625674962997437
# Error in Omega at the 2100 th iteration: 0.24995793402194977
# Error on the border of Omega at the 2100 th iteration: 2.9802322387695312e-08
# Error in Omega at the 2200 th iteration: 0.2499648928642273
# Error on the border of Omega at the 2200 th iteration: 2.9802322387695312e-08
# Error in Omega at the 2300 th iteration: 0.2499924898147583
# Error on the border of Omega at the 2300 th iteration: 2.9802322387695312e-08
# Error in Omega at the 2400 th iteration: 0.24964551627635956
# Error on the border of Omega at the 2400 th iteration: 2.9802322387695312e-08
# Error in Omega at the 2500 th iteration: 0.24990537762641907
# Error on the border of Omega at the 2500 th iteration: 2.9802322387695312e-08
# Error in Omega at the 2600 th iteration: 0.24995572865009308
# Error on the border of Omega at the 2600 th iteration: 2.9802322387695312e-08
# Error in Omega at the 2700 th iteration: 0.2499997317790985
# Error on the border of Omega at the 2700 th iteration: 1.4901161193847656e-08
# Error in Omega at the 2800 th iteration: 0.24986927211284637
# Error on the border of Omega at the 2800 th iteration: 2.9802322387695312e-08
# Error in Omega at the 2900 th iteration: 0.24999099969863892
# Error on the border of Omega at the 2900 th iteration: 2.9802322387695312e-08
# Error in Omega at the 3000 th iteration: 0.2499793916940689
# Error on the border of Omega at the 3000 th iteration: 2.9802322387695312e-08
# Error in Omega at the 3100 th iteration: 0.2499992698431015
# Error on the border of Omega at the 3100 th iteration: 2.9802322387695312e-08
# Error in Omega at the 3200 th iteration: 0.24999840557575226
# Error on the border of Omega at the 3200 th iteration: 2.9802322387695312e-08
# Error in Omega at the 3300 th iteration: 0.24964913725852966
# Error on the border of Omega at the 3300 th iteration: 2.9802322387695312e-08
# Error in Omega at the 3400 th iteration: 0.24999569356441498
# Error on the border of Omega at the 3400 th iteration: 2.9802322387695312e-08
# Error in Omega at the 3500 th iteration: 0.24989211559295654
# Error on the border of Omega at the 3500 th iteration: 2.9802322387695312e-08
# Error in Omega at the 3600 th iteration: 0.24999991059303284
# Error on the border of Omega at the 3600 th iteration: 2.9802322387695312e-08
# Error in Omega at the 3700 th iteration: 0.24999560415744781
# Error on the border of Omega at the 3700 th iteration: 2.9802322387695312e-08
# Error in Omega at the 3800 th iteration: 0.24999986588954926
# Error on the border of Omega at the 3800 th iteration: 2.9802322387695312e-08
# Error in Omega at the 3900 th iteration: 0.24999238550662994
# Error on the border of Omega at the 3900 th iteration: 2.9802322387695312e-08
# Error in Omega at the 4000 th iteration: 0.2499823272228241
# Error on the border of Omega at the 4000 th iteration: 2.9802322387695312e-08
# Error in Omega at the 4100 th iteration: 0.24998722970485687
# Error on the border of Omega at the 4100 th iteration: 2.9802322387695312e-08
# Error in Omega at the 4200 th iteration: 0.24999840557575226
# Error on the border of Omega at the 4200 th iteration: 2.9802322387695312e-08
# Error in Omega at the 4300 th iteration: 0.24991081655025482
# Error on the border of Omega at the 4300 th iteration: 2.9802322387695312e-08
# Error in Omega at the 4400 th iteration: 0.24998050928115845
# Error on the border of Omega at the 4400 th iteration: 2.9802322387695312e-08
# Error in Omega at the 4500 th iteration: 0.24987618625164032
# Error on the border of Omega at the 4500 th iteration: 2.9802322387695312e-08
# Error in Omega at the 4600 th iteration: 0.2498457133769989
# Error on the border of Omega at the 4600 th iteration: 2.9802322387695312e-08
# Error in Omega at the 4700 th iteration: 0.2499992549419403
# Error on the border of Omega at the 4700 th iteration: 2.9802322387695312e-08
# Error in Omega at the 4800 th iteration: 0.24999843537807465
# Error on the border of Omega at the 4800 th iteration: 2.9802322387695312e-08
# Error in Omega at the 4900 th iteration: 0.24999746680259705
# Error on the border of Omega at the 4900 th iteration: 2.9802322387695312e-08
# Error in Omega at the 5000 th iteration: 0.24954842031002045
# Error on the border of Omega at the 5000 th iteration: 2.9802322387695312e-08
# Error in Omega at the 5100 th iteration: 0.24999913573265076
# Error on the border of Omega at the 5100 th iteration: 2.9802322387695312e-08
# Error in Omega at the 5200 th iteration: 0.24998676776885986
# Error on the border of Omega at the 5200 th iteration: 2.9802322387695312e-08
# Error in Omega at the 5300 th iteration: 0.24991005659103394
# Error on the border of Omega at the 5300 th iteration: 2.9802322387695312e-08
# Error in Omega at the 5400 th iteration: 0.2499990463256836
# Error on the border of Omega at the 5400 th iteration: 2.9802322387695312e-08
# Error in Omega at the 5500 th iteration: 0.24999994039535522
# Error on the border of Omega at the 5500 th iteration: 2.9802322387695312e-08
# Error in Omega at the 5600 th iteration: 0.24999865889549255
# Error on the border of Omega at the 5600 th iteration: 2.9802322387695312e-08
# Error in Omega at the 5700 th iteration: 0.2499840259552002
# Error on the border of Omega at the 5700 th iteration: 2.9802322387695312e-08
# Error in Omega at the 5800 th iteration: 0.24997593462467194
# Error on the border of Omega at the 5800 th iteration: 2.9802322387695312e-08
# Error in Omega at the 5900 th iteration: 0.24990573525428772
# Error on the border of Omega at the 5900 th iteration: 2.9802322387695312e-08
# Error in Omega at the 6000 th iteration: 0.24999438226222992
# Error on the border of Omega at the 6000 th iteration: 2.9802322387695312e-08
# Error in Omega at the 6100 th iteration: 0.24999010562896729
# Error on the border of Omega at the 6100 th iteration: 2.9802322387695312e-08
# Error in Omega at the 6200 th iteration: 0.24999454617500305
# Error on the border of Omega at the 6200 th iteration: 2.9802322387695312e-08
# Error in Omega at the 6300 th iteration: 0.24990646541118622
# Error on the border of Omega at the 6300 th iteration: 2.9802322387695312e-08
# Error in Omega at the 6400 th iteration: 0.24999868869781494
# Error on the border of Omega at the 6400 th iteration: 2.9802322387695312e-08
# Error in Omega at the 6500 th iteration: 0.24999108910560608
# Error on the border of Omega at the 6500 th iteration: 2.9802322387695312e-08
# Error in Omega at the 6600 th iteration: 0.24997417628765106
# Error on the border of Omega at the 6600 th iteration: 2.9802322387695312e-08
# Error in Omega at the 6700 th iteration: 0.24998266994953156
# Error on the border of Omega at the 6700 th iteration: 2.9802322387695312e-08
# Error in Omega at the 6800 th iteration: 0.24999161064624786
# Error on the border of Omega at the 6800 th iteration: 2.9802322387695312e-08
# Error in Omega at the 6900 th iteration: 0.24999915063381195
# Error on the border of Omega at the 6900 th iteration: 2.9802322387695312e-08
# Error in Omega at the 7000 th iteration: 0.24998053908348083
# Error on the border of Omega at the 7000 th iteration: 2.9802322387695312e-08
# Error in Omega at the 7100 th iteration: 0.2499266415834427
# Error on the border of Omega at the 7100 th iteration: 2.9802322387695312e-08
# Error in Omega at the 7200 th iteration: 0.24999386072158813
# Error on the border of Omega at the 7200 th iteration: 2.9802322387695312e-08
# Error in Omega at the 7300 th iteration: 0.24998722970485687
# Error on the border of Omega at the 7300 th iteration: 2.9802322387695312e-08
# Error in Omega at the 7400 th iteration: 0.2499999701976776
# Error on the border of Omega at the 7400 th iteration: 2.9802322387695312e-08
# Error in Omega at the 7500 th iteration: 0.24997752904891968
# Error on the border of Omega at the 7500 th iteration: 2.9802322387695312e-08
# Error in Omega at the 7600 th iteration: 0.2499803602695465
# Error on the border of Omega at the 7600 th iteration: 2.9802322387695312e-08
# Error in Omega at the 7700 th iteration: 0.2498675435781479
# Error on the border of Omega at the 7700 th iteration: 2.9802322387695312e-08
# Error in Omega at the 7800 th iteration: 0.24993008375167847
# Error on the border of Omega at the 7800 th iteration: 2.9802322387695312e-08
# Error in Omega at the 7900 th iteration: 0.24984021484851837
# Error on the border of Omega at the 7900 th iteration: 2.9802322387695312e-08
# Error in Omega at the 8000 th iteration: 0.249943807721138
# Error on the border of Omega at the 8000 th iteration: 1.4901161193847656e-08
# Traning Completed.

# %%
import matplotlib.pyplot as plt

points=np.arange(-1,1,0.01)
xs,ys=np.meshgrid(points,points)
xs=torch.tensor(xs)
ys=torch.tensor(ys)
xl,yl=xs.size()
z=np.zeros((xl,yl))

for i in range(xl):
    for j in range(yl):      
        re=np.zeros(m)
        re[0]=xs[i][j]
        re[1]=ys[i][j]
        re=torch.tensor(re)        
        z[i][j]=model(re.float()).item()

fig=plt.figure()
ax=fig.add_subplot(111)
ax.imshow(z)
plt.show()

# %%
model.state_dict()
# Out:
# OrderedDict([('linear1.weight',
#               tensor([[-0.2092,  0.1361,  0.0780,  0.1315,  0.1947,  0.0843,  0.1846,
#                         0.3104,  0.0926, -0.2206],
#                       [-0.2483, -0.0207, -0.1775,  0.1632, -0.2064, -0.3035,  0.2630,
#                         0.2025,  0.0429, -0.3153],
#                       [-0.0505,  0.2415,  0.2804, -0.2930,  0.1795,  0.1079, -0.2927,
#                        -0.3083,  0.0316,  0.2897],
#                       [-0.2224, -0.1822, -0.1389,  0.1490,  0.2506, -0.1238,  0.3138,
#                         0.0015, -0.1234,  0.1603],
#                       [ 0.0097,  0.3130, -0.0660,  0.3074, -0.2805, -0.1529,  0.0548,
#                         0.2316,  0.0149, -0.0860],
#                       [-0.1591, -0.2327,  0.2681, -0.3145,  0.2550, -0.1384,  0.0043,
#                         0.1971, -0.3040,  0.1625],
#                       [-0.2293, -0.1094, -0.0528, -0.0843,  0.1030,  0.1963, -0.1135,
#                        -0.0785, -0.1855,  0.1872],
#                       [-0.0925,  0.2533, -0.0185, -0.0051,  0.0968, -0.1638, -0.0587,
#                         0.1768,  0.1982, -0.0029],
#                       [-0.2472, -0.1731,  0.3088,  0.2290,  0.1422,  0.0072, -0.0865,
#                         0.1438, -0.2300, -0.0019],
#                       [ 0.2727, -0.2523,  0.2972, -0.0216,  0.1066, -0.0553, -0.1569,
#                        -0.2031,  0.2218, -0.2943]])),
#              ('linear1.bias',
#               tensor([ 0.1205, -0.2690, -0.1990,  0.0801, -0.2248, -0.0842, -0.2615,
#                       -0.1960,  0.0726,  0.1042])),
#              ('linear2.weight',
#               tensor([[ 0.2472, -0.2569, -0.1040,  0.0476, -0.0143, -0.1071,  0.1854,
#                        -0.1827, -0.0800,  0.1571],
#                       [-0.1620, -0.0818, -0.2501, -0.0787, -0.1445,  0.0368, -0.0091,
#                         0.1437,  0.0999, -0.0929],
#                       [ 0.0573,  0.1784,  0.1461,  0.1043, -0.1398, -0.0486, -0.2256,
#                        -0.1543,  0.1907,  0.2215],
#                       [-0.1452, -0.0450,  0.0404, -0.2289,  0.2591,  0.1484,  0.2451,
#                         0.0270, -0.2026,  0.1765],
#                       [-0.2931,  0.0970,  0.1615,  0.1767,  0.1934,  0.0751,  0.1261,
#                         0.2081,  0.2345, -0.3140],
#                       [-0.0559, -0.2975,  0.2119,  0.2667,  0.0356, -0.2374, -0.2256,
#                        -0.0744, -0.2973,  0.2812],
#                       [ 0.1939, -0.2597, -0.3114,  0.2406,  0.1543, -0.0380,  0.0807,
#                         0.0248,  0.1965,  0.1886],
#                       [-0.0413, -0.2994,  0.0003, -0.0107,  0.0164,  0.2893, -0.2379,
#                        -0.2838,  0.0572, -0.1437],
#                       [ 0.1058,  0.3075, -0.0050,  0.2112, -0.1214, -0.1146,  0.1496,
#                        -0.2172,  0.1375, -0.0629],
#                       [-0.0581, -0.1474, -0.0933, -0.2485, -0.0955,  0.0055, -0.0048,
#                        -0.0714,  0.0037, -0.3000]])),
#              ('linear2.bias',
#               tensor([ 0.0049,  0.3021, -0.0020, -0.1317, -0.2824,  0.1776,  0.2988,
#                        0.1056, -0.2214, -0.0696])),
#              ('linear3.weight',
#               tensor([[-0.0973,  0.1851, -0.1524,  0.3150,  0.1452, -0.0587,  0.1925,
#                        -0.2858,  0.2597, -0.2908],
#                       [-0.1871,  0.2526, -0.2414, -0.0182, -0.2968,  0.2179, -0.2266,
#                         0.2172, -0.2008, -0.1136],
#                       [-0.0312,  0.2817,  0.1165,  0.2783, -0.0936, -0.3140, -0.1893,
#                         0.1681,  0.0541,  0.0268],
#                       [ 0.1603,  0.0711, -0.3121, -0.0035, -0.1499, -0.0611,  0.0400,
#                         0.1743,  0.0304, -0.0360],
#                       [-0.1179, -0.2902, -0.2367,  0.2155,  0.0188,  0.2765, -0.0900,
#                         0.2922, -0.2261, -0.2316],
#                       [-0.1138, -0.2635,  0.1790,  0.2008, -0.0634, -0.3058, -0.0575,
#                         0.0045, -0.0575, -0.0309],
#                       [ 0.0032, -0.2154, -0.1528, -0.1629,  0.2823, -0.2308,  0.1014,
#                        -0.0792, -0.1760, -0.1342],
#                       [ 0.1713, -0.0072,  0.0083,  0.2164,  0.0592, -0.2816, -0.2847,
#                         0.0589, -0.0689,  0.2415],
#                       [ 0.2395,  0.1890, -0.0278, -0.0426, -0.0101, -0.0188, -0.2943,
#                         0.0473,  0.1926, -0.1697],
#                       [ 0.0072, -0.2363,  0.1195,  0.1555,  0.3065, -0.2731, -0.1448,
#                        -0.1836,  0.1808,  0.2794]])),
#              ('linear3.bias',
#               tensor([-0.0380,  0.2717, -0.0153,  0.2269, -0.1178, -0.0221,  0.1076,
#                        0.2600, -0.0245, -0.1260])),
#              ('linear4.weight',
#               tensor([[ 0.2960,  0.2436, -0.2434, -0.3110,  0.1109,  0.2783,  0.0535,
#                        -0.0318, -0.0718, -0.1244],
#                       [-0.0356,  0.1111, -0.0087,  0.0357,  0.2847,  0.2663,  0.1199,
#                        -0.1916, -0.0776, -0.0166],
#                       [-0.0192,  0.2497,  0.1619,  0.0747,  0.3137, -0.2215,  0.1712,
#                         0.0549,  0.0096, -0.1152],
#                       [ 0.1903, -0.0566,  0.0384,  0.0655, -0.2544,  0.2830, -0.2537,
#                        -0.1814,  0.2473,  0.2944],
#                       [-0.2613,  0.1959,  0.2376,  0.1030, -0.0853,  0.0042, -0.2290,
#                         0.0148,  0.2601, -0.2039],
#                       [-0.1769,  0.0511, -0.0764, -0.0462,  0.0449, -0.0927, -0.2060,
#                        -0.1728, -0.0179,  0.0073],
#                       [-0.0436,  0.0596, -0.0298,  0.1472,  0.2601,  0.0539,  0.2270,
#                        -0.1375, -0.3039, -0.1098],
#                       [-0.2499, -0.0229, -0.1164,  0.0418,  0.1421, -0.0398,  0.0777,
#                        -0.1134,  0.1501,  0.2893],
#                       [-0.0292,  0.0397, -0.1943, -0.3005, -0.3106, -0.2558, -0.0542,
#                        -0.2937,  0.1536,  0.0416],
#                       [-0.1748, -0.1495,  0.1326, -0.1056, -0.1325, -0.0449,  0.2440,
#                         0.1076,  0.2509, -0.1446]])),
#              ('linear4.bias',
#               tensor([-0.3024,  0.2309, -0.0170,  0.1335,  0.0470, -0.2724,  0.1541,
#                        0.0083,  0.1477, -0.0246])),
#              ('linear5.weight',
#               tensor([[-0.1502, -0.0068,  0.0762,  0.1768, -0.1743,  0.0920, -0.2739,
#                         0.2230,  0.3047,  0.1768],
#                       [ 0.2236,  0.1802,  0.1965,  0.3147, -0.0773,  0.0314, -0.0712,
#                        -0.2069,  0.2118,  0.1932],
#                       [ 0.1018, -0.0070, -0.2699,  0.2310,  0.2041, -0.3151,  0.1915,
#                         0.1685,  0.1769,  0.1886],
#                       [ 0.3104,  0.0548,  0.3092,  0.0211, -0.0591,  0.0399,  0.1919,
#                         0.1342, -0.2705, -0.2580],
#                       [-0.0184,  0.0671, -0.1260,  0.2315,  0.0918,  0.1344, -0.0206,
#                         0.2278,  0.3138, -0.2898],
#                       [-0.1985, -0.2986,  0.2160,  0.1812, -0.0445,  0.0468,  0.1278,
#                        -0.0563,  0.2444, -0.0786],
#                       [ 0.1998, -0.2903,  0.0836,  0.1362, -0.2483, -0.0206,  0.1912,
#                        -0.0811, -0.3118,  0.0378],
#                       [ 0.3025,  0.0138, -0.0921,  0.3058, -0.3029,  0.2917, -0.1114,
#                        -0.1508,  0.1449,  0.0718],
#                       [-0.3124, -0.2326, -0.2668, -0.1281, -0.0294,  0.2408, -0.2897,
#                         0.0396, -0.2309, -0.0925],
#                       [ 0.1649, -0.0063, -0.3156,  0.2772, -0.1849,  0.1651, -0.0777,
#                         0.0231,  0.2285,  0.3071]])),
#              ('linear5.bias',
#               tensor([ 0.1925, -0.1515, -0.1613, -0.1160,  0.0218,  0.1496,  0.0656,
#                       -0.1054,  0.2211, -0.1739])),
#              ('linear6.weight',
#               tensor([[-0.1469, -0.2651,  0.3019,  0.0972, -0.0333, -0.2609, -0.0185,
#                         0.0155, -0.3095, -0.1356],
#                       [ 0.0003,  0.0525, -0.1617, -0.1042,  0.1686, -0.0149,  0.2391,
#                         0.1846,  0.3150, -0.2323],
#                       [ 0.0285,  0.2428,  0.0869, -0.0667, -0.1641,  0.1261, -0.3124,
#                        -0.1884, -0.0383,  0.1162],
#                       [ 0.1355, -0.2845, -0.1032,  0.1212, -0.1618,  0.2448, -0.2908,
#                        -0.2029,  0.1591, -0.2666],
#                       [-0.0261, -0.2053, -0.0261, -0.0283,  0.1102, -0.2173, -0.3065,
#                        -0.0245, -0.2149,  0.1499],
#                       [-0.2114,  0.1580, -0.3010, -0.2757,  0.0277, -0.0811,  0.1645,
#                        -0.0167, -0.1181,  0.1246],
#                       [-0.1020, -0.1947,  0.0872,  0.1929,  0.2551,  0.0951,  0.2444,
#                        -0.1786, -0.0443,  0.2303],
#                       [ 0.1934, -0.1052,  0.2934, -0.2262, -0.2983, -0.1365, -0.3060,
#                        -0.1382,  0.0990, -0.2221],
#                       [-0.0934,  0.1506, -0.2185, -0.1087,  0.2949,  0.1129, -0.1415,
#                        -0.2719,  0.2891,  0.1965],
#                       [-0.0726,  0.0213, -0.2895, -0.0350, -0.2775,  0.0557, -0.1697,
#                         0.2912,  0.0312,  0.1664]])),
#              ('linear6.bias',
#               tensor([ 0.1887, -0.2738,  0.1869, -0.1315, -0.0357, -0.2231,  0.1197,
#                        0.1914,  0.0755,  0.2974])),
#              ('linear7.weight',
#               tensor([[ 0.1788,  0.1175,  0.2537, -0.2389,  0.2914, -0.0815,  0.0801,
#                         0.0498,  0.2286, -0.0760]])),
#              ('linear7.bias', tensor([-0.2329]))])
