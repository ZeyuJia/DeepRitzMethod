# %%
import torch 
import torch.nn.functional as F
import numpy as np

torch.set_default_tensor_type('torch.FloatTensor')

m=10
learning_rate=1e-4
iterations=10000
print_every_iter=100
beta=1000
n1=1000 #number of points in (0,1)^m
n2=100  #number of points on the border of (0,1)^m
n3=100  #number of points used for evaluating the error

class DeepRitzNet(torch.nn.Module):
    def __init__(self, m):
        super(DeepRitzNet, self).__init__()
        self.linear1=torch.nn.Linear(m,m)
        self.linear2=torch.nn.Linear(m,m)
        self.linear3=torch.nn.Linear(m,m)
        self.linear4=torch.nn.Linear(m,m)
        self.linear5=torch.nn.Linear(m,m)
        self.linear6=torch.nn.Linear(m,m)
        
        self.linear7=torch.nn.Linear(m,1)
    
    def forward(self, x):
        y=(F.relu(self.linear1(x)))**3
        y=(F.relu(self.linear2(x)))**3
        y+=x
        x=y
        y=(F.relu(self.linear3(x)))**3
        y=(F.relu(self.linear4(x)))**3
        y+=x
        x=y
        y=(F.relu(self.linear5(x)))**3
        y=(F.relu(self.linear6(x)))**3
        y+=x
        y=(F.relu(self.linear7(x)))**3
        return y

#U_groundtruth has 10 arguements
def U_groundtruth(*args):
    re = 0
    for i in range(5):
        re += args[2*i]*args[2*i+1]
    return re

def border_sample():
    x=np.random.random_sample((m,))
    #randomly choose an integer between 0 and 999(including 0 and 999)
    dim=np.random.random_integers(0,m-1)
    
    if np.random.rand()<0.5:
        x[dim]=0
    else:
        x[dim]=1
        
    return x

# %%
model = DeepRitzNet(m)
#criterion=torch.nn.
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

for i in range(iterations):
    #sample n1=1000 points in (0,1)^m
    #x_in_omega is a list consisting n1=1000 tensors , each tensor has the shape of (m,)
    x_in_omega=[] 
    for t in range(n1):
        x_in_omega.append(torch.tensor(np.random.random_sample((m,)),requires_grad=True))
        
    #sample n2=100 points on the border of (0,1)^m
    #x_on_omega is a list consisting n2=100 tensors , each tensor has the shape of (m,)
    x_on_omega=[]
    for t in range(n2):
        x_on_omega.append(torch.tensor(border_sample(),requires_grad=True))
    
    #calculate the loss 
    loss=torch.zeros(1)
    for t in range(n1):
        #if I miss out the ".float()" there will be an error and I don't know why
        #It seems to have something to do with the usage of relu()**3 in DeepRitzNet
        y=model(x_in_omega[t].float())  
        y.backward()
        loss+=0.5*torch.sum((x_in_omega[t].grad.float())**2)
    loss/=n1
    
    regularization=torch.zeros(1)
    for t in range(n2):
        y=model(x_on_omega[t].float())
        regularization+=(y-U_groundtruth(*(x_on_omega[t].float()))**2)
    regularization*=beta/n2
    
    loss+=regularization
    
    #and step the optimizer
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    #print the error
    if((i+1)%print_every_iter==0):
        error=0
        for t in range(n3):
            x_test=torch.tensor(np.random.random_sample((m,)))
            error_instant=abs((model(x_test.float())-U_groundtruth(*(x_test.float()))).item())
            if error_instant>error:
                error = error_instant
        print("Error at the",i+1,"th iteration:",error)
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:53: DeprecationWarning: This function is deprecated. Please call randint(0, 9 + 1) instead
# Error at the 100 th iteration: 2.981895923614502
# Error at the 200 th iteration: 2.2827205657958984
# Error at the 300 th iteration: 2.3564436435699463
# Error at the 400 th iteration: 2.741673469543457
# Error at the 500 th iteration: 2.1753361225128174
# Error at the 600 th iteration: 2.685131549835205
# Error at the 700 th iteration: 2.5795114040374756
# Error at the 800 th iteration: 2.5025219917297363
# Error at the 900 th iteration: 3.0645809173583984
# Error at the 1000 th iteration: 2.735419988632202
# Error at the 1100 th iteration: 2.7210869789123535
# Error at the 1200 th iteration: 2.418586492538452
# Error at the 1300 th iteration: 2.7022993564605713
# Error at the 1400 th iteration: 2.82669997215271
# Error at the 1500 th iteration: 3.0066468715667725
# Error at the 1600 th iteration: 2.601874351501465
# Error at the 1700 th iteration: 2.927241325378418
# Error at the 1800 th iteration: 2.5326380729675293
# Error at the 1900 th iteration: 2.6290061473846436
# Error at the 2000 th iteration: 2.369248151779175
# Error at the 2100 th iteration: 2.8600106239318848
# Error at the 2200 th iteration: 3.0515525341033936
# Error at the 2300 th iteration: 2.4991989135742188
# Error at the 2400 th iteration: 3.076517343521118
# Error at the 2500 th iteration: 2.706697940826416
# Error at the 2600 th iteration: 2.5989863872528076
# Error at the 2700 th iteration: 2.888029098510742
# Error at the 2800 th iteration: 2.3476054668426514
# Error at the 2900 th iteration: 2.704010248184204
# Error at the 3000 th iteration: 3.1886682510375977
# Error at the 3100 th iteration: 2.3621082305908203
# Error at the 3200 th iteration: 2.7501325607299805
# Error at the 3300 th iteration: 2.3707540035247803
# Error at the 3400 th iteration: 2.681579351425171
# Error at the 3500 th iteration: 2.4625182151794434
# Error at the 3600 th iteration: 3.0231246948242188
# Error at the 3700 th iteration: 2.376771926879883
# Error at the 3800 th iteration: 2.532524585723877
# Error at the 3900 th iteration: 2.6152114868164062
# Error at the 4000 th iteration: 2.376971960067749
# Error at the 4100 th iteration: 2.9089200496673584
# Error at the 4200 th iteration: 2.5896782875061035
# Error at the 4300 th iteration: 2.8102056980133057
# Error at the 4400 th iteration: 2.2103919982910156
# Error at the 4500 th iteration: 2.449611186981201
# Error at the 4600 th iteration: 3.070838689804077
# Error at the 4700 th iteration: 2.531487226486206
# Error at the 4800 th iteration: 2.529176712036133
# Error at the 4900 th iteration: 2.944230079650879
# Error at the 5000 th iteration: 2.1773481369018555
# Error at the 5100 th iteration: 2.7015228271484375
# Error at the 5200 th iteration: 2.742663860321045
# Error at the 5300 th iteration: 2.417630195617676
# Error at the 5400 th iteration: 2.5076537132263184
# Error at the 5500 th iteration: 2.3910017013549805
# Error at the 5600 th iteration: 3.07322359085083
# Error at the 5700 th iteration: 2.4845685958862305
# Error at the 5800 th iteration: 2.4371604919433594
# Error at the 5900 th iteration: 2.3573970794677734
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-155-190560a9df67> in <module>()
#      20     for t in range(n1):
#      21         #if I miss out the ".float()" there will be an error and I don't know why
# ---> 22         y=model(x_in_omega[t].float())
#      23         y.backward()
#      24         loss+=0.5*torch.sum((x_in_omega[t].grad.float())**2)
#
# D:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# <ipython-input-147-a6748850bc78> in forward(self, x)
#      38         y=(F.relu(self.linear6(x)))**3
#      39         y+=x
# ---> 40         y=(F.relu(self.linear7(x)))**3
#      41         return y
#      42
#
# D:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py in relu(input, inplace)
#     617     if inplace:
#     618         return torch.relu_(input)
# --> 619     return torch.relu(input)
#     620
#     621
#
# KeyboardInterrupt:

# %%
# Out:
# [1]
